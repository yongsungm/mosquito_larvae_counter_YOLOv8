# %%
# !pip install -r requirements.txt

# %%
# Check for GPU
# !nvidia-smi

# %%
from ultralytics import YOLO

# %%
# load a pretrained model (recommended for training)
model = YOLO("yolov8n.pt")

# Tune hyperparameter for 30 epochs
model.tune(data='data.yaml', epochs=30, iterations=300, optimizer='AdamW', plots=False, save=False, val=False)
# Out:
# Tuner: Initialized Tuner instance with 'tune_dir=runs/detect/tune2'
# Tuner: 💡 Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/300 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Ultralytics YOLOv8.2.11 🚀 Python-3.11.8 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 11004MiB)
# ...

# %%
# load tuned hyperparameters and reset model for training
hyperparameters = 'runs/detect/tune/best_hyperparameters.yaml'
model = YOLO("yolov8n.pt")

# %%
#train the model
results = model.train(data="data.yaml", epochs=500, cfg=hyperparameters)
# Out:
# Ultralytics YOLOv8.2.11 🚀 Python-3.11.8 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 11004MiB)
# ...

# %%
model_path = "runs/detect/train/weights/best.pt"
model = YOLO(model_path)

# %%
# Test the model
metrics = model.val(data='test.yaml')  # run evaluation on test data
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.2.11 🚀 Python-3.11.8 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 11004MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /home/ydmasuda/final_project5/model_training/datasets/labels/test... 10 images, 1 backgrounds, 0 corrupt: 100%|██████████| 10/10 [00:00<00:00, 648.88it/s]
# val: New cache created: /home/ydmasuda/final_project5/model_training/datasets/labels/test.cache
# /home/ydmasuda/.local/lib/python3.11/site-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 1, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ...
